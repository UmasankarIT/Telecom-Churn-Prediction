# %%
import pandas as pd

df = pd.read_csv("telecom_feature_selected.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                       circle  year     month service_provider  \
# 0           0  Andaman and Nicobar Islands  2009     April           Aircel
# 1           1  Andaman and Nicobar Islands  2009  February           Aircel
# 2           2  Andaman and Nicobar Islands  2009   January           Aircel
# 3           3  Andaman and Nicobar Islands  2009     March           Aircel
# 4           4  Andaman and Nicobar Islands  2009       May           Aircel
#
#     value technology  tech_yearly_sum      tech_avg  tech_value_diff  \
# 0  852468         3G       7091626007  2.179738e+06              0.0
# 1  852468         3G       7091626007  2.179738e+06              0.0
# 2  852468         3G       7091626007  2.179738e+06              0.0
# 3  852468         3G       7091626007  2.179738e+06              0.0
# 4  852468         3G       7091626007  2.179738e+06              0.0
#
#    tech_yearly_share  technology_missing  value_lag1  value_lag2  \
# 0            0.00012                   0         0.0         0.0
# 1            0.00012                   0    852468.0         0.0
# 2            0.00012                   0    852468.0    852468.0
# 3            0.00012                   0    852468.0    852468.0
# 4            0.00012                   0    852468.0    852468.0
#
#    churn_change  churn
# 0           0.0      0
# 1           0.0      0
# 2           0.0      0
# 3           0.0      0
# 4           0.0      0

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df.tail()
# Out:
#             circle  year     month service_provider     value technology  \
# 65886  West Bengal  2025  February    Vodafone-Idea       150         5G
# 65887  West Bengal  2025   January    Vodafone-Idea  11742282         5G
# 65888  West Bengal  2025   January    Vodafone-Idea       150         5G
# 65889  West Bengal  2025     March    Vodafone-Idea  11620668         5G
# 65890  West Bengal  2025     March    Vodafone-Idea       150         5G
#
#        tech_yearly_sum      tech_avg  tech_value_diff  tech_yearly_share  \
# 65886       4347862126  9.005452e+06        -284090.0       3.449971e-08
# 65887       4347862126  9.005452e+06      -12387806.0       2.700702e-03
# 65888       4347862126  9.005452e+06        -279230.0       3.449971e-08
# 65889       4347862126  9.005452e+06      -12774587.0       2.672731e-03
# 65890       4347862126  9.005452e+06        -290657.0       3.449971e-08
#
#        technology_missing  value_lag1  value_lag2  churn_change  churn
# 65886                   0  11722068.0       150.0   -11721918.0      1
# 65887                   0       150.0  11722068.0    11742132.0      0
# 65888                   0  11742282.0       150.0   -11742132.0      1
# 65889                   0       150.0  11742282.0    11620518.0      0
# 65890                   0  11620668.0       150.0   -11620518.0      1

# %%
from sklearn.preprocessing import LabelEncoder

label_encoders = {}  # to save each encoder

for col in ['circle', 'technology', 'service_provider', 'month']:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le  # save encoder for later decoding

# %%
df.head()
# Out:
#    circle  year  month  service_provider   value  technology  tech_yearly_sum  \
# 0       0  2009      0                 1  852468           0       7091626007
# 1       0  2009      3                 1  852468           0       7091626007
# 2       0  2009      4                 1  852468           0       7091626007
# 3       0  2009      7                 1  852468           0       7091626007
# 4       0  2009      8                 1  852468           0       7091626007
#
#        tech_avg  tech_value_diff  tech_yearly_share  technology_missing  \
# 0  2.179738e+06              0.0            0.00012                   0
# 1  2.179738e+06              0.0            0.00012                   0
# 2  2.179738e+06              0.0            0.00012                   0
# 3  2.179738e+06              0.0            0.00012                   0
# 4  2.179738e+06              0.0            0.00012                   0
#
#    value_lag1  value_lag2  churn_change  churn
# 0         0.0         0.0           0.0      0
# 1    852468.0         0.0           0.0      0
# 2    852468.0    852468.0           0.0      0
# 3    852468.0    852468.0           0.0      0
# 4    852468.0    852468.0           0.0      0

# %%
from sklearn.ensemble import RandomForestClassifier

X = df.drop(columns=['churn', 'churn_change','value'])  # value is not predictive
y = df['churn']

model = RandomForestClassifier(random_state=42, n_estimators=100)
model.fit(X, y)

importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': model.feature_importances_
}).sort_values(by='Importance', ascending=False).reset_index(drop=True)

print("\nFeature Importance:\n", importance_df)
# Out:
# Feature Importance:
#                 Feature  Importance
# 0           value_lag1    0.403232
# 1    tech_yearly_share    0.219572
# 2           value_lag2    0.119942
# 3      tech_value_diff    0.089285
# 4     service_provider    0.047325
# 5                month    0.038835
# 6      tech_yearly_sum    0.029586
# 7                 year    0.023677
# 8               circle    0.017992
# 9             tech_avg    0.005727
# 10          technology    0.004827
# 11  technology_missing    0.000000

# %%
# Choose a threshold (e.g., >0.01 importance)
selected_features = importance_df[importance_df['Importance'] > 0.01]['Feature'].tolist()

# Always add churn back
df_selected = df[selected_features + ['churn']]

# %%
df_selected.tail()
# Out:
#        value_lag1  tech_yearly_share  value_lag2  tech_value_diff  \
# 65886  11722068.0       3.449971e-08       150.0        -284090.0
# 65887       150.0       2.700702e-03  11722068.0      -12387806.0
# 65888  11742282.0       3.449971e-08       150.0        -279230.0
# 65889       150.0       2.672731e-03  11742282.0      -12774587.0
# 65890  11620668.0       3.449971e-08       150.0        -290657.0
#
#        service_provider  month  tech_yearly_sum  year  circle  churn
# 65886                26      3       4347862126  2025      29      1
# 65887                26      4       4347862126  2025      29      0
# 65888                26      4       4347862126  2025      29      1
# 65889                26      7       4347862126  2025      29      0
# 65890                26      7       4347862126  2025      29      1

# %%
for col in ['circle', 'technology', 'service_provider', 'month']:
    df[col] = label_encoders[col].inverse_transform(df[col])

# %%
df.head()
# Out:
#                         circle  year     month service_provider   value  \
# 0  Andaman and Nicobar Islands  2009     April           Aircel  852468
# 1  Andaman and Nicobar Islands  2009  February           Aircel  852468
# 2  Andaman and Nicobar Islands  2009   January           Aircel  852468
# 3  Andaman and Nicobar Islands  2009     March           Aircel  852468
# 4  Andaman and Nicobar Islands  2009       May           Aircel  852468
#
#   technology  tech_yearly_sum      tech_avg  tech_value_diff  \
# 0         3G       7091626007  2.179738e+06              0.0
# 1         3G       7091626007  2.179738e+06              0.0
# 2         3G       7091626007  2.179738e+06              0.0
# 3         3G       7091626007  2.179738e+06              0.0
# 4         3G       7091626007  2.179738e+06              0.0
#
#    tech_yearly_share  technology_missing  value_lag1  value_lag2  \
# 0            0.00012                   0         0.0         0.0
# 1            0.00012                   0    852468.0         0.0
# 2            0.00012                   0    852468.0    852468.0
# 3            0.00012                   0    852468.0    852468.0
# 4            0.00012                   0    852468.0    852468.0
#
#    churn_change  churn
# 0           0.0      0
# 1           0.0      0
# 2           0.0      0
# 3           0.0      0
# 4           0.0      0

# %%
df.to_csv("selected_features.csv", index=False)
